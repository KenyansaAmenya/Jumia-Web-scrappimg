# %%
pip install selenium bs4 webdriver_manager
# Out:
# Requirement already satisfied: selenium in c:\users\user\anaconda3\lib\site-packages (4.33.0)
# Requirement already satisfied: bs4 in c:\users\user\anaconda3\lib\site-packages (0.0.2)
# Requirement already satisfied: webdriver_manager in c:\users\user\anaconda3\lib\site-packages (4.0.2)
# Requirement already satisfied: urllib3~=2.4.0 in c:\users\user\anaconda3\lib\site-packages (from urllib3[socks]~=2.4.0->selenium) (2.4.0)
# Requirement already satisfied: trio~=0.30.0 in c:\users\user\anaconda3\lib\site-packages (from selenium) (0.30.0)
# Requirement already satisfied: trio-websocket~=0.12.2 in c:\users\user\anaconda3\lib\site-packages (from selenium) (0.12.2)
# Requirement already satisfied: certifi>=2025.4.26 in c:\users\user\anaconda3\lib\site-packages (from selenium) (2025.4.26)
# Requirement already satisfied: typing_extensions~=4.13.2 in c:\users\user\anaconda3\lib\site-packages (from selenium) (4.13.2)
# Requirement already satisfied: websocket-client~=1.8.0 in c:\users\user\anaconda3\lib\site-packages (from selenium) (1.8.0)
# Requirement already satisfied: beautifulsoup4 in c:\users\user\anaconda3\lib\site-packages (from bs4) (4.12.3)
# Requirement already satisfied: requests in c:\users\user\anaconda3\lib\site-packages (from webdriver_manager) (2.32.3)
# Requirement already satisfied: python-dotenv in c:\users\user\anaconda3\lib\site-packages (from webdriver_manager) (0.21.0)
# Requirement already satisfied: packaging in c:\users\user\anaconda3\lib\site-packages (from webdriver_manager) (24.1)
# Requirement already satisfied: attrs>=23.2.0 in c:\users\user\anaconda3\lib\site-packages (from trio~=0.30.0->selenium) (25.3.0)
# Requirement already satisfied: sortedcontainers in c:\users\user\anaconda3\lib\site-packages (from trio~=0.30.0->selenium) (2.4.0)
# Requirement already satisfied: idna in c:\users\user\anaconda3\lib\site-packages (from trio~=0.30.0->selenium) (3.7)
# Requirement already satisfied: outcome in c:\users\user\anaconda3\lib\site-packages (from trio~=0.30.0->selenium) (1.3.0.post0)
# Requirement already satisfied: sniffio>=1.3.0 in c:\users\user\anaconda3\lib\site-packages (from trio~=0.30.0->selenium) (1.3.0)
# Requirement already satisfied: cffi>=1.14 in c:\users\user\anaconda3\lib\site-packages (from trio~=0.30.0->selenium) (1.17.1)
# Requirement already satisfied: wsproto>=0.14 in c:\users\user\anaconda3\lib\site-packages (from trio-websocket~=0.12.2->selenium) (1.2.0)
# Requirement already satisfied: pysocks!=1.5.7,<2.0,>=1.5.6 in c:\users\user\anaconda3\lib\site-packages (from urllib3[socks]~=2.4.0->selenium) (1.7.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\user\anaconda3\lib\site-packages (from beautifulsoup4->bs4) (2.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\user\anaconda3\lib\site-packages (from requests->webdriver_manager) (3.3.2)
# Requirement already satisfied: pycparser in c:\users\user\anaconda3\lib\site-packages (from cffi>=1.14->trio~=0.30.0->selenium) (2.21)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\users\user\anaconda3\lib\site-packages (from wsproto>=0.14->trio-websocket~=0.12.2->selenium) (0.14.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from bs4 import BeautifulSoup
import time

# %%
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()))
url = "https://www.jumia.co.ke/dining-entertaining-teacups/ceramics--generic/#catalog-listing"

driver.get(url)

time.sleep(5)

soup = BeautifulSoup(driver.page_source, 'html.parser')

products = soup.find_all('div', class_='info')

product_list = []

for product in products:
    name = product.find('h3', class_='name').text if product.find('h3', class_='name') else 'no names'
    current_price = product.find('div', class_='prc').text if product.find('div', class_='prc') else 'No price'
    old_price = product.find('div', class_='old').text if product.find('div', class_='old') else 'No old price'
    discount = product.find('div', class_='bdg _dsct _sm').text if product.find('div', class_='bdg _dsct _sm') else 'no discount'

    product_list.append( {
        'name': name,
        'current price': current_price,
        'old_price': old_price,
        'discount': discount
    })

driver.quit()

# %%
product_list
# Out:
# [{'name': '350ml Dried Flower Double Wall Glass Cup with Handle Heat Resistant ',
#   'current price': 'KSh 759',
#   'old_price': 'KSh 2,000',
#   'discount': '62%'},
#  {'name': '6pcs Ceramic Mug Set Ceramic Cups For Coffee, Latte, Cappuccino, Tea,',
#   'current price': 'KSh 1,289',
#   'old_price': 'KSh 2,000',
#   'discount': '36%'},
#  {'name': 'Ceramics Classy cups with golden deco. Set of 6 pcs',
#   'current price': 'KSh 1,799',
#   'old_price': 'KSh 2,500',
#   'discount': '28%'},
#  {'name': 'Beautiful And Classy Ceramic Mugs/Cups For Tea/Coffee-Set(6)',
#   'current price': 'KSh 985',
#   'old_price': 'KSh 1,800',
#   'discount': '45%'},
#  {'name': 'Brass Chalice Cup Glasses Champagne Glasses Beverage Goblet Cup Gold Vintage Creative For Bar Home Decor',
#   'current price': 'KSh 1,659',
#   'old_price': 'KSh 2,238',
#   'discount': '26%'},
#  {'name': 'Chinese Wuyi Lapsang Souchong Black Tea Zipper Bag Tea Seal Pocket Packaging No Packing Bag',
#   'current price': 'KSh 2,940',
#   'old_price': 'KSh 3,964',
#   'discount': '26%'},
#  {'name': '*Good Morning Printed Glass Mug with Handle ',
#   'current price': 'KSh 699',
#   'old_price': 'KSh 999',
#   'discount': '30%'},
#  {'name': '6pcs set cups',
#   'current price': 'KSh 1,200',
#   'old_price': 'KSh 1,400',
#   'discount': '14%'},
#  {'name': '350ml Dried Flower Double Wall Glass Cup with Handle Heat Resistant ',
#   'current price': 'KSh 790',
#   'old_price': 'KSh 1,500',
#   'discount': '47%'},
#  {'name': '12 Pcs Deco Cup Nice One',
#   'current price': 'KSh 1,999',
#   'old_price': 'KSh 3,000',
#   'discount': '33%'},
#  {'name': '1pc 300ml White Bone China',
#   'current price': 'KSh 1,400',
#   'old_price': 'KSh 1,800',
#   'discount': '22%'},
#  {'name': 'Classic Ceramic Mugs For Tea/Coffee Set(6) (Vikombe)',
#   'current price': 'KSh 960',
#   'old_price': 'KSh 1,200',
#   'discount': '20%'},
#  {'name': '12pc cup and saucer',
#   'current price': 'KSh 3,500',
#   'old_price': 'No old price',
#   'discount': 'no discount'},
#  {'name': 'Gratitude Is The Best Attitude Mug',
#   'current price': 'KSh 750',
#   'old_price': 'KSh 1,000',
#   'discount': '25%'},
#  {'name': '6 Set Signature TOP QUALITY 32 Cl Signature Mugs',
#   'current price': 'KSh 2,300',
#   'old_price': 'KSh 2,700',
#   'discount': '15%'},
#  {'name': 'Camera Tumblers For Your Kids',
#   'current price': 'KSh 1,332',
#   'old_price': 'KSh 4,533',
#   'discount': '71%'},
#  {'name': '350ml Dried Flower Double Wall Glass Cup with Handle Heat Resistant ',
#   'current price': 'KSh 1,100',
#   'old_price': 'KSh 2,000',
#   'discount': '45%'},
#  {'name': 'Blue And White Porcelain Teacup Chinese Kung Fu Tea Bowl For Puer Ceramic Atique Glaze Master Cup Kitchen Tea Set Accessories',
#   'current price': 'KSh 1,834',
#   'old_price': 'KSh 2,481',
#   'discount': '26%'},
#  {'name': 'Luminarc Cortina 31cl Glass',
#   'current price': 'KSh 2,600',
#   'old_price': 'KSh 2,700',
#   'discount': '4%'},
#  {'name': 'Ceramic kids cup',
#   'current price': 'KSh 1,360',
#   'old_price': 'No old price',
#   'discount': 'no discount'},
#  {'name': '1000ml Large Glass Cute Cartoon Clear Cup With Handle And Lid Straw Coffee Milk Juice Cups Heat Resistance Milk Mug',
#   'current price': 'KSh 1,847',
#   'old_price': 'KSh 2,495',
#   'discount': '26%'},
#  {'name': '6pcs 32 cl Mugs Snowdrops Charming and Elegant',
#   'current price': 'KSh 2,200',
#   'old_price': 'KSh 2,800',
#   'discount': '21%'},
#  {'name': 'Set Of 6 Signature Cups',
#   'current price': 'KSh 1,755',
#   'old_price': 'KSh 5,500',
#   'discount': '68%'},
#  {'name': 'Creative Glass Drinking Horn Viking Horn Cup For Mead Ale And Stemmed Glass',
#   'current price': 'KSh 1,861',
#   'old_price': 'KSh 2,508',
#   'discount': '26%'},
#  {'name': '1000ml Glass Cups With Lid And Straw Drinkware Cute Coffee Mugs Big Glasses For Drinks Water Tea Korean Milk Juice Cup',
#   'current price': 'KSh 1,241',
#   'old_price': 'KSh 1,672',
#   'discount': '26%'},
#  {'name': 'Signature 6 Set TOP QUALITY 32 Cl Mugs',
#   'current price': 'KSh 2,400',
#   'old_price': 'KSh 2,700',
#   'discount': '11%'},
#  {'name': 'Ceramic Classic White Cups. Set Of 6 Pcs',
#   'current price': 'KSh 1,800 - KSh 2,090',
#   'old_price': 'KSh 1,900 - KSh 2,500',
#   'discount': '16%'},
#  {'name': '6 pcs Set 32cl Mugs Aqua Spray Design Refreshing and Stylish',
#   'current price': 'KSh 2,200',
#   'old_price': 'KSh 2,800',
#   'discount': '21%'},
#  {'name': 'Chinese Tea Cups Porcelain Celadon Fish Teacup Set Loose Leaf Teapot Drinkware Oolong Tea Ceramic Kung Fu Tea Sets',
#   'current price': 'KSh 1,025',
#   'old_price': 'KSh 1,389',
#   'discount': '26%'},
#  {'name': '6 Pcs Creative Glass Cups Cute Ripple Shaped Vintage Drinking Glasses Ribbed Glassware Aesthetic Cups Entertainment Dinnerware',
#   'current price': 'KSh 2,104',
#   'old_price': 'KSh 2,845',
#   'discount': '26%'},
#  {'name': 'Good Morning Coffee Mug Transparent Breakfast Cup Heat Resistant Glass Cup Teacup Iced Juice Water Cup Glass Drinkware',
#   'current price': 'KSh 836',
#   'old_price': 'KSh 1,133',
#   'discount': '26%'},
#  {'name': '400ml Grape Shape Glass Cup Heat Resistant Coffee Mug Teacup Transparent Breakfast Cup Iced Juice Drink Cup Tumbler',
#   'current price': 'KSh 1,038',
#   'old_price': 'KSh 1,402',
#   'discount': '26%'},
#  {'name': 'Cartoon Cute Glass Water Cup Modern Classic Coffee Ice Latte Juice Milk Breakfast Cup Ins Style Personal Business',
#   'current price': 'KSh 1,281',
#   'old_price': 'KSh 1,726',
#   'discount': '26%'},
#  {'name': "300/400ml High-Resistant Irregular Circle Glass Water Glass Ice Americano Latte Coffee Cup Cold Drink Cup Valentine's Day",
#   'current price': 'KSh 1,807',
#   'old_price': 'KSh 2,441',
#   'discount': '26%'},
#  {'name': 'Weird Ice American Glass Latte Coffee Cup Ins Wind Cold Drink Juice Cup Transparent Female Milk Tea Water Glass',
#   'current price': 'KSh 2,387',
#   'old_price': 'KSh 3,223',
#   'discount': '26%'},
#  {'name': 'Set of 6 Signature Cups',
#   'current price': 'KSh 2,755',
#   'old_price': 'KSh 5,500',
#   'discount': '50%'},
#  {'name': 'Thermos Bottle Insulated Water Smart Vacuum Stainless Cup',
#   'current price': 'KSh 804',
#   'old_price': 'KSh 1,339',
#   'discount': '40%'},
#  {'name': 'Garden Pots Plant  Net Cups Thin Lip & Slotted Sides Cup for Indoor or Outdoor Growing NO5242',
#   'current price': 'KSh 219 - KSh 1,881',
#   'old_price': 'KSh 405 - KSh 3,241',
#   'discount': '48%'},
#  {'name': 'Stainless Steel Food Clip Hand Shaped Tea Cup Clip Ice Clips Mini Sugar Tongs NO5232',
#   'current price': 'KSh 145',
#   'old_price': 'KSh 270',
#   'discount': '46%'},
#  {'name': '2pcs (one large and one small) Chalice Goblet Pentagram Altar Goblet Chalice Divination',
#   'current price': 'KSh 1,745',
#   'old_price': 'KSh 5,772',
#   'discount': '70%'}]

# %%
import pandas as pd

# %%
df = pd.DataFrame(product_list)

# %%
df.head()
# Out:
#                                                 name current price  old_price  \
# 0  350ml Dried Flower Double Wall Glass Cup with ...       KSh 759  KSh 2,000
# 1  6pcs Ceramic Mug Set Ceramic Cups For Coffee, ...     KSh 1,289  KSh 2,000
# 2  Ceramics Classy cups with golden deco. Set of ...     KSh 1,799  KSh 2,500
# 3  Beautiful And Classy Ceramic Mugs/Cups For Tea...       KSh 985  KSh 1,800
# 4  Brass Chalice Cup Glasses Champagne Glasses Be...     KSh 1,659  KSh 2,238
#
#   discount
# 0      62%
# 1      36%
# 2      28%
# 3      45%
# 4      26%
